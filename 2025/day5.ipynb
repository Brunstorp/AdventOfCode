# %%
import os
from dotenv import load_dotenv
from aocd import get_data, submit

from get_aoc_test_data import get_aoc_test_data

load_dotenv()

session = os.getenv("AOC_SESSION")

data = get_data(day=5, year=2025, session=session)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 5
#       2 from dotenv import load_dotenv
#       3 from aocd import get_data, submit
# ----> 5 from get_aoc_test_data import get_aoc_test_data
#       7 load_dotenv()
#       9 session = os.getenv("AOC_SESSION")
#
# ImportError: cannot import name 'get_aoc_test_data' from 'get_aoc_test_data' (/Users/elliotbrunstorp/Desktop/AdventOfCode/2025/get_aoc_test_data.py)
